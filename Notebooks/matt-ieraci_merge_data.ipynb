# %%
import pandas as pd

# %%
# import cleaned true csv
true_df = pd.read_csv('../data/true_cleaned.csv')
true_df
# Out:
#                                                     text  is_fake
# 0      The head of a conservative Republican faction ...        0
# 1      Transgender people will be allowed for the fir...        0
# 2      The special counsel investigation of links bet...        0
# 3      Trump campaign adviser George Papadopoulos tol...        0
# 4      President Donald Trump called on the U.S. Post...        0
# ...                                                  ...      ...
# 21187  NATO allies on Tuesday welcomed President Dona...        0
# 21188  LexisNexis, a provider of legal, regulatory an...        0
# 21189  In the shadow of disused Soviet-era factories ...        0
# 21190  Vatican Secretary of State Cardinal Pietro Par...        0
# 21191  Indonesia will buy 11 Sukhoi fighter jets wort...        0
#
# [21192 rows x 2 columns]

# %%
# import cleaned fake csv
fake_df = pd.read_csv('../data/fake_cleaned.csv')
fake_df
# Out:
#                                                     text  is_fake
# 0      Donald Trump just couldn t wish all Americans ...        1
# 1      House Intelligence Committee Chairman Devin Nu...        1
# 2      On Friday, it was revealed that former Milwauk...        1
# 3      On Christmas day, Donald Trump announced that ...        1
# 4      Pope Francis used his annual Christmas Day mes...        1
# ...                                                  ...      ...
# 17461  21st Century Wire says All the world s a stage...        1
# 17462    Randy Johnson 21st Century WireThe majority ...        1
# 17463  Tune in to the Alternate Current Radio Network...        1
# 17464  21st Century Wire says A new front has just op...        1
# 17465  21st Century Wire says It s not that far away....        1
#
# [17466 rows x 2 columns]

# %%
merge_df = pd.concat([fake_df, true_df]).reset_index(drop=True)
merge_df
# Out:
#                                                     text  is_fake
# 0      Donald Trump just couldn t wish all Americans ...        1
# 1      House Intelligence Committee Chairman Devin Nu...        1
# 2      On Friday, it was revealed that former Milwauk...        1
# 3      On Christmas day, Donald Trump announced that ...        1
# 4      Pope Francis used his annual Christmas Day mes...        1
# ...                                                  ...      ...
# 38653  NATO allies on Tuesday welcomed President Dona...        0
# 38654  LexisNexis, a provider of legal, regulatory an...        0
# 38655  In the shadow of disused Soviet-era factories ...        0
# 38656  Vatican Secretary of State Cardinal Pietro Par...        0
# 38657  Indonesia will buy 11 Sukhoi fighter jets wort...        0
#
# [38658 rows x 2 columns]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/hannadinizcunha/Downloads/WELFake_Dataset.csv', index_col=0)

# %%
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1                                                    NaN
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3      Bobby Jindal, raised Hindu, uses story of Chri...
# 4      SATAN 2: Russia unvelis an image of its terrif...
# ...                                                  ...
# 72129  Russians steal research on Trump in hack of U....
# 72130   WATCH: Giuliani Demands That Democrats Apolog...
# 72131  Migrants Refuse To Leave Train At Refugee Camp...
# 72132  Trump tussle gives unpopular Mexican leader mu...
# 72133  Goldman Sachs Endorses Hillary Clinton For Pre...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# 1         Did they post their votes for Hillary already?      1
# 2       Now, most of the demonstrators gathered last ...      1
# ...

# %%
df = df.drop_duplicates(ignore_index=True)

# %%
df = df.dropna()

# %%
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3      Bobby Jindal, raised Hindu, uses story of Chri...
# 4      SATAN 2: Russia unvelis an image of its terrif...
# 5      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 63673  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 63674  Russians steal research on Trump in hack of U....
# 63675   WATCH: Giuliani Demands That Democrats Apolog...
# 63676  Migrants Refuse To Leave Train At Refugee Camp...
# 63677  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label
# 0      No comment is expected from Barack Obama Membe...      1
# 2       Now, most of the demonstrators gathered last ...      1
# 3      A dozen politically active pastors came here f...      0
# ...

# %%
total = []

for n in df['text']:
    total.append(len(n.split(" ")))
    
sum(total)/len(df['text'])
# Out:
# 556.4417230398758

# %%
df['total'] = total

# %%
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 2      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 3      Bobby Jindal, raised Hindu, uses story of Chri...
# 4      SATAN 2: Russia unvelis an image of its terrif...
# 5      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 63673  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 63674  Russians steal research on Trump in hack of U....
# 63675   WATCH: Giuliani Demands That Democrats Apolog...
# 63676  Migrants Refuse To Leave Train At Refugee Camp...
# 63677  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  total
# 0      No comment is expected from Barack Obama Membe...      1    941
# 2       Now, most of the demonstrators gathered last ...      1     38
# ...

# %%
df.sort_values('total').head(50)
# Out:
#                                                    title  \
# 5719   BREAKING: MITT ROMNEY Speaks To Reporters Foll...
# 27640  WOW! TUCKER AND JESSE Destroy The Liberal Kook...
# 3693   FOOTBALL LEGEND JIM KELLY: “Donald Trump took ...
# 28240  DEAR DEMOCRATS AND LIBERALS…Stop Complaining A...
# 421    HEATED! TUCKER CARLSON Totally Shuts Down Radi...
# 15600  TRUMP SUPPORTER Whose Brutal Beating By Black ...
# 52272  WATCH KELLYANNE CONWAY vs Total Jerk Chris Cuo...
# 36498  BOOM! TOMI LARHEN Destroys The Idiotic “Day Wi...
# 20168  “THANK YOU BABY”…YES, FEMINISTS WILL GO NUTS: ...
# 16575  GIVE ‘EM HELL JESSE: Shouldn’t you Democrats s...
# 36885  THE VIEW’S Whoopi Goldberg To Co-Host: “This I...
# 50970  JESSE WATTERS PANEL Goes Off Rails While Debat...
# 11220  Judge Jeanine Gets to The Bottom of “Towergate...
# 18534  Why Hillary Clinton's Campaign Is Collapsing |...
# 16749  RADICAL DIRECTOR OF SIERRA CLUB: Abortion is t...
# ...

# %%
df = df[df['total'] > 100]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      Bobby Jindal, raised Hindu, uses story of Chri...
# 2      SATAN 2: Russia unvelis an image of its terrif...
# 3      About Time! Christian Group Sues Amazon and SP...
# 4      Sports Bar Owner Bans NFL Games…Will Show Only...
# ...                                                  ...
# 56200  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 56201  Russians steal research on Trump in hack of U....
# 56202   WATCH: Giuliani Demands That Democrats Apolog...
# 56203  Migrants Refuse To Leave Train At Refugee Camp...
# 56204  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  total
# 0      No comment is expected from Barack Obama Membe...      1    941
# 1      A dozen politically active pastors came here f...      0   1290
# ...

# %%
df.sort_values('total')
# Out:
#                                                    title  \
# 11293  المغاربة يذهلون العالم ويبتكرون طريقة لتجفيف ا...
# 44033  Franken: GOP Colleagues Questioning Trump’s Me...
# 12910  Morocco arrests six suspected Islamic State mi...
# 42800        Hurricane Irma moves away from Barbuda: NHC
# 14348  WATCH BARACK Become Agitated When CNN Ally Con...
# ...                                                  ...
# 55885  Re: 55 Reasons Why California Is The Worst Sta...
# 15098  Re: How Many People Will Have To Migrate Out O...
# 5678   Заседание Международного дискуссионного клуба ...
# 28776  Re: Why Are So Many People Choosing To Leave T...
# 290    Re: The Hard Working American vs. The Governme...
#
#                                                     text  label  total
# 11293  المغاربة يذهلون العالم ويبتكرون طريقة لتجفيف ا...      1    101
# 44033  Sunday on CNN’s “State of the Union,” Sen. Al ...      0    101
# ...

# %%
sum(df['total'])/len(df['text'])
# Out:
# 617.9499332799573

# %%
df
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      Bobby Jindal, raised Hindu, uses story of Chri...
# 2      SATAN 2: Russia unvelis an image of its terrif...
# 3      About Time! Christian Group Sues Amazon and SP...
# 4      Sports Bar Owner Bans NFL Games…Will Show Only...
# ...                                                  ...
# 56200  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 56201  Russians steal research on Trump in hack of U....
# 56202   WATCH: Giuliani Demands That Democrats Apolog...
# 56203  Migrants Refuse To Leave Train At Refugee Camp...
# 56204  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  total
# 0      No comment is expected from Barack Obama Membe...      1    941
# 1      A dozen politically active pastors came here f...      0   1290
# ...

# %%
df.to_csv('../raw_data/new_df_clean.csv', index=False)

# %%
df['text'][1319]
# Out:
# '(Reuters) - NBC has suspended television personality Billy Bush from the “Today” show after fallout over the host’s 2005 taped lewd conversation with U.S. Republican presidential nominee Donald Trump, according to a show memo seen by Reuters on Sunday. The suspension comes as a flood of Republicans have withdrawn their support for Trump over the video that emerged on Friday showing the businessman, then a reality TV star, talking with Bush on an open microphone about groping women and trying to seduce a married woman. In the recorded conversation, Trump was chatting on a bus with Bush, then host of NBC’s “Access Hollywood,” ahead of a segment they were about to tape. Bush said in a statement to Variety on Friday he was “embarrassed and ashamed” of his comments. NBC said Bush had been suspended indefinitely from the “Today” show, where he hosts the third hour of programming.  Noah Oppenheim, the executive in charge of the morning show, wrote in a memo to staff that “there is simply n
# ...

# %%
weird = []

if np.dtype(df['label']) != int:
    weird.append(df['text'])

# %%
weird
# Out:
# []
